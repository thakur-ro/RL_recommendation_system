# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict

# %%
data = pd.read_csv('dataset/sample_df.csv')

# %%
data
# Out:
#               item            user  rating   timestamp
# 0       0972683275  A1MNILX1J1NWV7     4.0  1464825600
# 1       0972683275  A1JPB4BJHNCSWR     5.0  1409184000
# 2       0972683275  A2A3B0JX2JRS6S     5.0  1379462400
# 3       0972683275  A14O9P3DV5EHKO     3.0  1359331200
# 4       0972683275  A2BLGQ2SCSKCCY     5.0  1358812800
# ...            ...             ...     ...         ...
# 111242  B01H4OYJNI  A2QIFKUBK053ZC     5.0  1531008000
# 111243  B01H4YTHWG  A2SOSDOBI6AHJI     5.0  1537920000
# 111244  B01H4ZLZLQ  A3CHC46D65IH4H     4.0  1536019200
# 111245  B01HGV7M7Y  A1F7KIIWHPQ5TG     5.0  1537142400
# 111246  B01HGV7M7Y  A1FNPF8RU9JX2K     4.0  1532649600
#
# [111247 rows x 4 columns]

# %%
df = data.copy()

# %%
df.item.nunique()
# Out:
# 13283

# %%
unique_users = data['user'].unique()
unique_items = data['item'].unique()

# %%
user_dict = defaultdict(int)
item_dict = defaultdict(int)
for i, user in enumerate(unique_users):
    user_dict[user] = i
    
for i, item in enumerate(unique_items):
    item_dict[item] = i

# %%
historic_users = []

for i, user in enumerate(unique_users):
    temp = df[df['user'] == user]
    temp = temp.sort_values('timestamp').reset_index(drop=True)
    historic_users.append(temp)

for user in historic_users:
    user['timestamp'] += user.index

# %%
historic_users[1]
# Out:
#           item            user  rating   timestamp
# 0   B00IVPU7AO  A1JPB4BJHNCSWR     5.0  1408492800
# 1   B00BGUG9DK  A1JPB4BJHNCSWR     5.0  1408492801
# 2   B0002EOFFK  A1JPB4BJHNCSWR     1.0  1408492802
# 3   B003XM9774  A1JPB4BJHNCSWR     5.0  1409184003
# 4   B004G605Q8  A1JPB4BJHNCSWR     4.0  1409184004
# 5   0972683275  A1JPB4BJHNCSWR     5.0  1409184005
# 6   B00DR0RBV6  A1JPB4BJHNCSWR     3.0  1421020806
# 7   B017A62ZUO  A1JPB4BJHNCSWR     5.0  1464825607
# 8   B00SI67YRU  A1JPB4BJHNCSWR     4.0  1481241608
# 9   B016JREG84  A1JPB4BJHNCSWR     5.0  1481241609
# 10  B000FNFSPY  A1JPB4BJHNCSWR     5.0  1481241610
# 11  B00UVN20T0  A1JPB4BJHNCSWR     4.0  1500595211
# 12  B000BTL0OA  A1JPB4BJHNCSWR     4.0  1500595212
# 13  B00IOS6EAU  A1JPB4BJHNCSWR     5.0  1500595213
# 14  B004CAJUCI  A1JPB4BJHNCSWR     5.0  1500595214
# 15  B005BCAKO8  A1JPB4BJHNCSWR     5.0  1500595215
# 16  B01GF4XZ24  A1JPB4BJHNCSWR     5.0  1500595216
# 17  B012M8LXQW  A1JPB4BJHNCSWR     4.0  1500940817
# 18  B00CO0DDZS  A1JPB4BJHNCSWR     4.0  1500940818
# 19  B00FX6KO8Y  A1JPB4BJHNCSWR     5.0  1500940819
# 20  B008VQ8IKY  A1JPB4BJHNCSWR     4.0  1500940820
# 21  B00B7JLZSE  A1JPB4BJHNCSWR     5.0  1500940821
# 22  B004CADY9I  A1JPB4BJHNCSWR     4.0  1500940822
# 23  B002LE8BJA  A1JPB4BJHNCSWR     5.0  1500940823
# 24  B001UI4RTG  A1JPB4BJHNCSWR     5.0  1500940824
# 25  B000A6PPOK  A1JPB4BJHNCSWR     5.0  1500940825
# 26  B00BEZZBFO  A1JPB4BJHNCSWR     5.0  1500940826
# 27  B008B6ONXK  A1JPB4BJHNCSWR     5.0  1501113627
# 28  B000HPV3RW  A1JPB4BJHNCSWR     4.0  1501113628
# 29  B00C0Y6BQG  A1JPB4BJHNCSWR     4.0  1501113629
# 30  B00KF9IVKC  A1JPB4BJHNCSWR     4.0  1501804830
# 31  B000OTEZ5I  A1JPB4BJHNCSWR     5.0  1517184031
# 32  B0007TOR08  A1JPB4BJHNCSWR     5.0  1517184032

# %%
user_movies = defaultdict(list) #list of rated movies by each user
for user_df in historic_users:
    user = user_df['user'][0]
    user_movies[user] = [item_dict[x] for x in user_df['item']]

# %%
x=np.zeros((1, 13283))
x.shape
# Out:
# (1, 13283)

# %%
max(sorted(list(item_dict.values()))) + 1
# Out:
# 13283

# %%
list(item_dict.values())[-1] + 1
# Out:
# 13282

# %%
user_id = 'A1JPB4BJHNCSWR'
user_movies_count = len(user_movies[user_id])
user_movies_count
# Out:
# 33

# %%
random_index = np.random.randint(0, user_movies_count-1) 
random_index
# Out:
# 10

# %%
target = np.zeros((1, 13283))
target[0][user_movies[user_id][random_index]] = 1

# %%
print(user_movies[user_id][random_index])
# Out:
# 896

# %%
print(target[0][896])
# Out:
# 1.0

# %%
context = np.zeros((1, 13283))

# %%
context[0][user_movies[user_id][:random_index] + user_movies[user_id][random_index+1:]] = 1

# %%
print(user_movies[user_id][:random_index])
# Out:
# [8005, 5770, 472, 2536, 2860, 0, 6506, 12009, 10047, 11888]

# %%
print(user_movies[user_id][random_index+1:])
# Out:
# [10396, 756, 7943, 2803, 3462, 13100, 11335, 6145, 7136, 4858, 5641, 2801, 2109, 1841, 705, 5747, 4745, 960, 5938, 8405, 1166, 622]

# %%
context[0][756]
# Out:
# 1.0

# %%
batch = [self.generate_input(user_id=np.random.choice(self.train_users) - 1) for _ in range(batch_size)]
X_train = np.array([b[0] for b in batch])
y_train = np.array([b[1] for b in batch])

# %%
class Embeddings:
    def __init__(self, data, train_test_ratio):
        self.data = data
        # list of unique users
        self.unique_users = data['user'].unique()
        # list of unique items
        self.unique_items = data['item'].unique()
        # count of unique items
        self.unique_items_count = data['item'].nunique()
        # mapping of user_id to integer
        self.users_dict = self.create_item_index_mapping(self.unique_users)
        # mapping of item_id to integer
        self.items_dict = self.create_item_index_mapping(self.unique_items)
        # list of dataframes of users' sorted rating history
        self.user_history_arr = self.create_history(self.data, self.unique_users)
        # number of training users
        total_training_users = int(train_test_ratio * len(user_history_arr))
        # train_test_split
        self.train_users = self.user_history_arr[:total_training_users]
        self.test_users = self.user_history_arr[total_training_users:]
        # dictionary of users having ratings sorted by timestamp
        self.user_ratings_dict = self.create_user_rating_list(self.user_history_arr)
    
    def create_item_index_mapping(arr):
        t_dict = defaultdict(int)
        for i, val in enumerate(arr):
            t_dict[val] = i
        return t_dict
    
    def create_user_rating_list(historic_users):
        user_ratings = defaultdict(list) #list of rated movies by each user
        for user_df in historic_users:
            user = user_df['user'][0]
            user_ratings[user] = [self.items_dict[x] for x in user_df['item']]

    def create_history(df, unique_users):
        historic_users = []

        for i, user in enumerate(unique_users):
            temp = df[df['user'] == user]
            temp = temp.sort_values('timestamp').reset_index(drop=True)
            historic_users.append(temp)
        # TO ACCOUNT FOR EQUAL TIMESTAMP
        for user in historic_users:
            user['timestamp'] += user.index
        return historic_users
    
    def create_input(self, user_id):
        user_ratings_count = len(self.user_ratings_dict[user_id])
        random_index = np.random.randint(0, user_ratings_count - 1)
        target = np.zeros((1, self.unique_items_count))
        target[0][self.user_ratings_dict[user_id][random_index]] = 1
        
        context = np.zeros((1, self.unique_items_count))
        target[0][self.user_ratings_dict[user_id][:random_index] + self.user_ratings_dict[user_id][random_index+1]] = 1
        
        return context, target
    
    def model(self, hidden_layer_size=512):
        m = Sequential()
        m.add(Dense(hidden_layer_size, input_shape=(1, self.unique_items_count)))
        m.add(Dropout(0.1))
        m.add(Dense(hidden_layer_size//2))
        m.add(Dropout(0.2))
        m.add(Dense(self.unique_items_count, activation='softmax'))
        m.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', 'loss'])
        return m

# %%
historic_users[1]
# Out:
#           item            user  rating   timestamp
# 0   B00IVPU7AO  A1JPB4BJHNCSWR     5.0  1408492800
# 1   B00BGUG9DK  A1JPB4BJHNCSWR     5.0  1408492801
# 2   B0002EOFFK  A1JPB4BJHNCSWR     1.0  1408492802
# 3   B003XM9774  A1JPB4BJHNCSWR     5.0  1409184003
# 4   B004G605Q8  A1JPB4BJHNCSWR     4.0  1409184004
# 5   0972683275  A1JPB4BJHNCSWR     5.0  1409184005
# 6   B00DR0RBV6  A1JPB4BJHNCSWR     3.0  1421020806
# 7   B017A62ZUO  A1JPB4BJHNCSWR     5.0  1464825607
# 8   B00SI67YRU  A1JPB4BJHNCSWR     4.0  1481241608
# 9   B016JREG84  A1JPB4BJHNCSWR     5.0  1481241609
# 10  B000FNFSPY  A1JPB4BJHNCSWR     5.0  1481241610
# 11  B00UVN20T0  A1JPB4BJHNCSWR     4.0  1500595211
# 12  B000BTL0OA  A1JPB4BJHNCSWR     4.0  1500595212
# 13  B00IOS6EAU  A1JPB4BJHNCSWR     5.0  1500595213
# 14  B004CAJUCI  A1JPB4BJHNCSWR     5.0  1500595214
# 15  B005BCAKO8  A1JPB4BJHNCSWR     5.0  1500595215
# 16  B01GF4XZ24  A1JPB4BJHNCSWR     5.0  1500595216
# 17  B012M8LXQW  A1JPB4BJHNCSWR     4.0  1500940817
# 18  B00CO0DDZS  A1JPB4BJHNCSWR     4.0  1500940818
# 19  B00FX6KO8Y  A1JPB4BJHNCSWR     5.0  1500940819
# 20  B008VQ8IKY  A1JPB4BJHNCSWR     4.0  1500940820
# 21  B00B7JLZSE  A1JPB4BJHNCSWR     5.0  1500940821
# 22  B004CADY9I  A1JPB4BJHNCSWR     4.0  1500940822
# 23  B002LE8BJA  A1JPB4BJHNCSWR     5.0  1500940823
# 24  B001UI4RTG  A1JPB4BJHNCSWR     5.0  1500940824
# 25  B000A6PPOK  A1JPB4BJHNCSWR     5.0  1500940825
# 26  B00BEZZBFO  A1JPB4BJHNCSWR     5.0  1500940826
# 27  B008B6ONXK  A1JPB4BJHNCSWR     5.0  1501113627
# 28  B000HPV3RW  A1JPB4BJHNCSWR     4.0  1501113628
# 29  B00C0Y6BQG  A1JPB4BJHNCSWR     4.0  1501113629
# 30  B00KF9IVKC  A1JPB4BJHNCSWR     4.0  1501804830
# 31  B000OTEZ5I  A1JPB4BJHNCSWR     5.0  1517184031
# 32  B0007TOR08  A1JPB4BJHNCSWR     5.0  1517184032

# %%
user_dict
# Out:
# defaultdict(int,
#             {'A1MNILX1J1NWV7': 0,
#              'A1JPB4BJHNCSWR': 1,
#              'A2A3B0JX2JRS6S': 2,
#              'A14O9P3DV5EHKO': 3,
#              'A2BLGQ2SCSKCCY': 4,
#              'A21OS6PWQG5YOO': 5,
#              'AYKXABHFBFGJX': 6,
#              'A39KBWLS6TURMR': 7,
#              'A6J8D9V5S9MBE': 8,
#              'AUGBCGUG05AH7': 9,
#              'A1HQTQQXV5P2UG': 10,
#              'A3B75JRYE07CH': 11,
#              'A3IQR99TNNWNKF': 12,
#              'A2V90RN1G4M11V': 13,
#              'A36QF2CX91ONJC': 14,
#              'A2RFAKR9FU6VGT': 15,
#              'A3ISJB3FVYHL1U': 16,
#              'A2KLSFIQUUNTJ8': 17,
#              'A3923UGIPX0QQM': 18,
#              'ACZP9RHD3W7GO': 19,
#              'A2ICKE6A3MJMM5': 20,
#              'A6VFSC0BW75Y0': 21,
#              'ALEG9QCIUWK81': 22,
#              'A1D4O9JOOP7S3C': 23,
#              'AV6BQVVC1XE4E': 24,
#              'A3MDA891A1EPT8': 25,
#              'ADKYANLVMPKSC': 26,
#              'A2E80ZZ6Y8ZJT1': 27,
#              'A356YCP3ZPMBGD': 28,
#              'A3SA31EJDM4BO9': 29,
#              'A30VZQ2CVUYLQ1': 30,
#              'A3DDDKAS16QCGQ': 31,
#              'A2A5JHRL2NNKA7': 32,
#              'A1NCVERYR6HSBS': 33,
#              'AF8B7MM264A2P': 34,
#              'A227FZFWWJUPJF': 35,
#              'A2T96G1WFBHQUE': 36,
#              'AETQIN7OH0RL9': 37,
#              'ATX8SITVMGY15': 38,
#              'A3L63YZGH1ET8Y': 39,
#              'A3R54PYQ2CBXK8': 40,
#              'A117PS4BRXBZCN': 41,
#              'ACO3JMLZX3IPI': 42,
#              'A2I1KFM5JETZPX': 43,
#              'A15DIP9QPUR6IR': 44,
#              'AS3UP4A0F2L94': 45,
#              'A2GYF9DIZYILKE': 46,
#              'A3673PFILKTD7U': 47,
#              'A10NQKIG7NXUR7': 48,
#              'A2NBGIUKE54UN8': 49,
#              'A1NFFTOPMXWTPL': 50,
#              'A1M3NKEPI9R8BH': 51,
#              'A1S8PFQ6FXI4PD': 52,
#              'A3KSM3QHKAYZ31': 53,
#              'A1TBVI7YBSSY2K': 54,
#              'A16O3O8CNC80HA': 55,
#              'A3RCXMPSN1887Q': 56,
#              'A2A4YBNFV76DGA': 57,
#              'AILKGRMLEMGXC': 58,
#              'A78J38NU18DDZ': 59,
#              'A31K5W6NWK68OA': 60,
#              'A3U8J6HOIYKIFM': 61,
#              'A3PGAICBV5O6QR': 62,
#              'A1O3FYVHHWC8CJ': 63,
#              'A378EDLWSGTQ4V': 64,
#              'A1AZ3AZ8I5DQ3': 65,
#              'A11ULAZ4B5ZXC8': 66,
#              'A3D8LTHSN5P47Z': 67,
#              'A2PSMNDRT6PRB4': 68,
#              'A2885ZJCQWRXAH': 69,
#              'AMP6GGLHAHDAE': 70,
#              'A2TF3AOCIM6HP4': 71,
#              'A1RBJP1ZBIIT7': 72,
#              'A6N0NBG6Z13G5': 73,
#              'AXR4MDGWSXNYC': 74,
#              'A24P4E3RJ6AX94': 75,
#              'A3LJ2XUYKO6F2': 76,
#              'A7HEZCAYG5JML': 77,
#              'A3EGCYJ41MWIFD': 78,
#              'A3IIAEIVEA9ZNR': 79,
#              'A15U1Z3N0L3C12': 80,
#              'A18PAD4ISAH6KU': 81,
#              'A1P7GKSA09Z20U': 82,
#              'A3MMVTD7DA3PJ8': 83,
#              'A3KOASATK1KTI': 84,
#              'A5L0A7RHUNOXK': 85,
#              'A7Y6AVS576M03': 86,
#              'A3QX0ERX4D03TF': 87,
#              'A3ANRNLZ2LVM8J': 88,
#              'A24B12OG6NW0WH': 89,
#              'A1OU2FW26L47VV': 90,
#              'ABI7M9PHNDEOC': 91,
#              'A3HNMDZLMAX9H9': 92,
#              'A22TJPZOUI9DE1': 93,
#              'A1RZUJ4V9QZKI0': 94,
#              'A30CV4T4I9Y89P': 95,
#              'AHE4RU04NVDHR': 96,
#              'AZD8SMNGQI98O': 97,
#              'A3V1A3C9DTLPME': 98,
#              'A4J3TDUXO8MUP': 99,
#              'A1QBOC76MIOJYP': 100,
#              'A2GQS16NHRJGPM': 101,
#              'A3E0R5R2DGYLGN': 102,
#              'A2CI5S1KVURZCQ': 103,
#              'A3VX9A5C3DR2KC': 104,
#              'A1PO9VNIADLB6D': 105,
#              'A3RM7UXPGPOYLX': 106,
#              'AZ7BO8QW86I10': 107,
#              'A1FI7JYOXSWCCA': 108,
#              'A17GIJ1CCP7B1F': 109,
#              'A1K5X2LO8SU14V': 110,
#              'ALDETGLJV606L': 111,
#              'AW3J97Q4JZ2RY': 112,
#              'A3CW7FXPJB69XW': 113,
#              'A3CEC4CVNG98ZT': 114,
#              'A36Y0YSVLVOVVY': 115,
#              'AI9WUEEFVHY3K': 116,
#              'A7ETH68ZA6I4S': 117,
#              'A2XC0AE25I3V9E': 118,
#              'A3RNIG506NCWWO': 119,
#              'A1KJRNFAO7K5S5': 120,
#              'AMFXT0836BF87': 121,
#              'A253X5E4L0DM0W': 122,
#              'A3NWP4CG5S2PDE': 123,
#              'A2LZSPR192KEX6': 124,
#              'A3M2XNAG6HL4EZ': 125,
#              'ANH9TJFSO2YFJ': 126,
#              'A1RMOES5FGRF00': 127,
#              'A3FYLBYT96LVVK': 128,
#              'A14BMRL64GVD93': 129,
#              'A2T9E9RPWGBH96': 130,
#              'A12XHO23XDM515': 131,
#              'A3SL7BXUHLRKW3': 132,
#              'A2IUE299OONA73': 133,
#              'A1NDASR7O3U6B7': 134,
#              'A1GXN3IXX92SV0': 135,
#              'A2LSLKVVNQ92A': 136,
#              'AS1E6X67ZJ7WQ': 137,
#              'A34OS716X8ANZT': 138,
#              'AJ201A07AP4TL': 139,
#              'A3EFZZY5DUHLVS': 140,
#              'A127GZ51PD786F': 141,
#              'A3TPEPYMO2GFN7': 142,
#              'A2PATWWZAXHQYA': 143,
#              'A3MRAQJ2PYG64S': 144,
#              'A3N8RWAP4NG8Q9': 145,
#              'A13MLH6MLX7O45': 146,
#              'A1IR8UXPNFC0H3': 147,
#              'AIVXTGTFIH4Y4': 148,
#              'AMF75VWP2SV6M': 149,
#              'A1VSJ1YD40Y7PG': 150,
#              'A1GIRH2N6B2VZL': 151,
#              'A2EBAZQBTR7QNZ': 152,
#              'A1X5K5AFPF2LNJ': 153,
#              'A36D2DQXJAQQA9': 154,
#              'AMUNMW13QBFVS': 155,
#              'A2SAI9GPI7NLK': 156,
#              'A3AGSFLNNIFKNJ': 157,
#              'A231WM2Z2JL0U3': 158,
#              'A2MU20PYVR6JKS': 159,
#              'A3A8F4HE4YY4BM': 160,
#              'A1MHPGANXXGLC8': 161,
#              'A1ST7HGW72SKM2': 162,
#              'A1KBCCPD4CGNRX': 163,
#              'A20FNHFR9IUCWV': 164,
#              'APA32I4XCRA4A': 165,
#              'A1UCX2JQRCSMFY': 166,
#              'A1SC5HC35S2372': 167,
#              'AFGYC0XW6O50A': 168,
#              'A2XZ17154XY887': 169,
#              'ARTA78TP6H73D': 170,
#              'A3J9IYWJ6V2XZA': 171,
#              'ANQMEH2G3Z28C': 172,
#              'A1APGU5L0DWCR1': 173,
#              'A1S7SNHX4IMZ44': 174,
#              'A3POOQMFOLS1B7': 175,
#              'A248LSBZT4P38V': 176,
#              'A2IBUZECB34CMS': 177,
#              'A234GO3KZYKKTE': 178,
#              'A28SG5KPAYNQWN': 179,
#              'A3OS5Q3V8BCSVP': 180,
#              'A33N9BVJ4LJUTG': 181,
#              'AVD9577W9EV2J': 182,
#              'A2E9JUH38M9BLR': 183,
#              'A2PLMQBUKG06L9': 184,
#              'A2Q9FOL85UK8RA': 185,
#              'A1ZETCHKWICN6K': 186,
#              'A3A77O5509C17K': 187,
#              'A3T8ISGIQ27V3X': 188,
#              'A32SUIEEW3K443': 189,
#              'A3F4X1NNK36IR7': 190,
#              'A2WS0U0603Z04P': 191,
#              'A2RJW4DPSKQI5P': 192,
#              'A1UC3ZU18PE9B3': 193,
#              'AG3Y5X5REQ7XR': 194,
#              'A60URGWRQFM7R': 195,
#              'ADBGPR5L7NVSJ': 196,
#              'A26RIG340ORKA0': 197,
#              'A3E6HFD7U91DY': 198,
#              'ANX51Y0Y4TXAK': 199,
#              'A1QHMFVUTVIAY': 200,
#              'A1FLMSQGKKHSFR': 201,
#              'A226AQW5LH1HXO': 202,
#              'A32FN9RNY65CKH': 203,
#              'ARYNSVFEHHOE1': 204,
#              'A2S13NSRLNW59V': 205,
#              'A119ZRP5ZH6T6P': 206,
#              'A4JYFR3IWASS0': 207,
#              'A2BRXREMT5WZJ0': 208,
#              'A2U01Q5WKTZ8QP': 209,
#              'AAW4JYVF4B845': 210,
#              'A35Z3TBNCQU3VY': 211,
#              'A2CXHJECJ8R0QL': 212,
#              'A34F1Y0N0QAR3Y': 213,
#              'A30UHM6OOPVHNA': 214,
#              'A1JEJEDR7NDZ7C': 215,
#              'A20AID8HF1K3VG': 216,
#              'A15ZWZKUIPUUVH': 217,
#              'A2H6BSS1LDKJ6U': 218,
#              'A2MBSC4S2PJNRD': 219,
#              'A25RXG4QNHG3JZ': 220,
#              'A380AG0XY0DRZZ': 221,
#              'A2GT8WJGBIEVWK': 222,
#              'ANE3LU1E8NZJO': 223,
#              'ALPKH1BLNWPFK': 224,
#              'A1XMRTK9WU30W8': 225,
#              'A2FNOZBDE1G7JL': 226,
#              'A4OPNK2K0EDLG': 227,
#              'A21U2CZHHWYWAH': 228,
#              'AB3070H7XMUFS': 229,
#              'A2CZLJ6W1AUJZM': 230,
#              'ASJBQG73574ZZ': 231,
#              'A3H7W0DDG266QY': 232,
#              'A2X869XQTVNDW2': 233,
#              'ANV2AKYYI04EU': 234,
#              'AQ27PNANUHDDU': 235,
#              'A3IQKWA25HVA5U': 236,
#              'APG2BHOAXPNEQ': 237,
#              'A28NAK2GT0YR9I': 238,
#              'AFUBIHEP3H76O': 239,
#              'A19TOWNSAKCFFR': 240,
#              'A1UEQ4RFJBMGYJ': 241,
#              'A3REYP3W0BLUNA': 242,
#              'A2TUXUOKJHAYCI': 243,
#              'A272Y6VXIMOKSF': 244,
#              'A36MHSUQIH1XJE': 245,
#              'A3HE9I4GQ4OXYE': 246,
#              'AMYQVXWY2MIFK': 247,
#              'A32S0E9JAFY4MH': 248,
#              'A3LNNQ4JPUTJVI': 249,
#              'A3FGOOWBV8SUCA': 250,
#              'AOI57C0MJUT6J': 251,
#              'A26X7W5UM5QFT4': 252,
#              'A2SM7HA647C4M2': 253,
#              'A3N1C3ZLVB9GS4': 254,
#              'A1JXNDR68ZJZX4': 255,
#              'A3OAMLAS8LYVAY': 256,
#              'A1BWP4J9E1VX8L': 257,
#              'A1AOQ9TZT9YG49': 258,
#              'A27PNH29CY07L2': 259,
#              'A3E8V347DZ0ZIZ': 260,
#              'AFUASKJPBTBTD': 261,
#              'A30R2SFLSIAM67': 262,
#              'A189WZVG2YYL69': 263,
#              'A2FJ0Z5T726V6': 264,
#              'ATT44BYJLR56A': 265,
#              'A2WBNJP5EFJYMI': 266,
#              'A19YVVAD6X98BP': 267,
#              'A3TTVIQ9RRHNIB': 268,
#              'AA4W6F7VT4ME7': 269,
#              'A19E3ZCQH6TJBD': 270,
#              'A4GS8B8G3Q7QE': 271,
#              'A2HZLT6N4OLB4J': 272,
#              'AK2Q71S6H40PQ': 273,
#              'A143LJ4G2OPP7T': 274,
#              'A2T48324YQHU56': 275,
#              'A1R19YYR5OR26T': 276,
#              'A1BM6NLEP612WN': 277,
#              'A3UWM2JGOASDI4': 278,
#              'A1NC57HORXH9TB': 279,
#              'A1CVZ5HF40D32P': 280,
#              'A2KTK6JRVV1615': 281,
#              'A3UOLEH1EH1RTH': 282,
#              'A320CVDUI84KVC': 283,
#              'A1DDSRM0ZYY6I8': 284,
#              'A1UALUAGCN7UMX': 285,
#              'A3V24Y0Q3SDJIH': 286,
#              'A1D2GUF6EWYVQQ': 287,
#              'AG6XXHC7GAXBF': 288,
#              'A14CPYHGLRH3N7': 289,
#              'ADWAH7ASDJ0YZ': 290,
#              'AVT3JF4FZK5I2': 291,
#              'A2JN0LKB8PAEU9': 292,
#              'AEY7TJ82NP21X': 293,
#              'A2BFH1VK6JTYNV': 294,
#              'A35AU6SGVRYJZ0': 295,
#              'A22ZI4FO8J3W0': 296,
#              'A35Q0RBM3YNQNF': 297,
#              'A2XK8WOE7ZP52G': 298,
#              'ACWI476GB6NT3': 299,
#              'AAJ7RUTWEYC3B': 300,
#              'A39OM6SPWHS3FK': 301,
#              'A2E6A49WGDYWFA': 302,
#              'A2HLXJBE9N7MPQ': 303,
#              'AAUXZRNDAPH2D': 304,
#              'A2HOPYNO8PMUHP': 305,
#              'A10OVC2MHYOBZZ': 306,
#              'A21CDQWIG6D0UR': 307,
#              'A10BMHSLDHDLCL': 308,
#              'AHS500V3DHSJN': 309,
#              'ASQ5357GTL3PV': 310,
#              'A1RTNYQYIOJT24': 311,
#              'A366V0GCEPH5CX': 312,
#              'A1E6ILRSSEWU4C': 313,
#              'A3D3B790CQD07W': 314,
#              'A297R44X7WEQ8T': 315,
#              'A20D5SQ51S7ETH': 316,
#              'A36VH5B1T6CFOD': 317,
#              'A1SEAZ7BHFPRPD': 318,
#              'A5EPN0VVF9EHZ': 319,
#              'A2ZFUXX2QDQZ05': 320,
#              'A3SH2CYGMKNN9O': 321,
#              'A3TMKO1DO08TQY': 322,
#              'A7DNERCNQB3QQ': 323,
#              'A13YHP6GYXZAEX': 324,
#              'A3E1YE200T0RNO': 325,
#              'A450WKBT9ZIM': 326,
#              'AP9ADCGZFVJ37': 327,
#              'A58N07M0ZCYMB': 328,
#              'A1ACWV1YPB4J8T': 329,
#              'A2H4GOUSEAYGEO': 330,
#              'ASR72SFVOMOCK': 331,
#              'A2MJXZGMRLW9JV': 332,
#              'A1GZZEI9LGAIRQ': 333,
#              'A2NCO79BXDXVCQ': 334,
#              'AH1KJ45IQTM4T': 335,
#              'AUITG1DJ3QUGK': 336,
#              'A54JYLX8TY2ST': 337,
#              'AQOJHLLFE14GV': 338,
#              'A3A9QXSTQ5R9OA': 339,
#              'A2XPMSIJQ5SVH5': 340,
#              'A3GGOU7B5NVAIS': 341,
#              'A3DR7IVA6QC3JT': 342,
#              'AUEMXGEH4Y226': 343,
#              'A2O168CJIAEGL5': 344,
#              'A228B35PGJ9S8I': 345,
#              'A3F2M27L02YDLM': 346,
#              'A2M9TM9ERNFHNY': 347,
#              'A3N8SCPIJCGDKR': 348,
#              'A207L6A5HAC24B': 349,
#              'A33MRJH4XK9Q7': 350,
#              'A314SSFZKE4FVN': 351,
#              'A3PVA1Y953L9W8': 352,
#              'A1L7PNPU593K1T': 353,
#              'AJORB1WFEXZ3T': 354,
#              'A2UOSX86FZJ4Y9': 355,
#              'A3G3LITI9EWHPM': 356,
#              'A1OQOXOEFOCAU0': 357,
#              'A21D7IZG6TO2WO': 358,
#              'A2APB91IQZTJ80': 359,
#              'A1G9JCB54XMLAW': 360,
#              'AFDA4WD64VWOK': 361,
#              'A3NBMO2DQ7HGGN': 362,
#              'ATLWQV9V1F3MC': 363,
#              'A3KQUCP8LZ3BBY': 364,
#              'A2JWWEHHIDO04E': 365,
#              'A3IINWVUF47H15': 366,
#              'A3RGPLX4F1P545': 367,
#              'A2IXYZC295D33D': 368,
#              'AFI21QXLFNAWA': 369,
#              'AR3N1VLW722V9': 370,
#              'A30QPTW3XXDBB1': 371,
#              'A11NFFG2EQD1X6': 372,
#              'A35V7AV13VMCCS': 373,
#              'A3TSSUMP82WNRO': 374,
#              'AWO32HN0KS1HC': 375,
#              'A1BZ77ZXQ3INBJ': 376,
#              'A2EAW9C31JE4L6': 377,
#              'A1X7X8KB9NXPAA': 378,
#              'A1R2OKFC8GP6DE': 379,
#              'A2UWPFYTMPW6S5': 380,
#              'A20361V1Y2GZ5X': 381,
#              'A29CT3MXKBWVQ6': 382,
#              'A2F1V6JKYFP67M': 383,
#              'A3KY5RJPX71812': 384,
#              'A2B5F8N1BO2CQA': 385,
#              'A2RMTTDT5Z6G86': 386,
#              'A1JFIUTWHXQZ9P': 387,
#              'A1YZ7EO0W5CK7X': 388,
#              'A2CC64YAXZPDJB': 389,
#              'A3N57AGAL4B3OI': 390,
#              'A32WNX1QWF08VG': 391,
#              'A19Q4JC53BX7KB': 392,
#              'A36JLQHD7LB337': 393,
#              'A3DRT9IRH63ZHB': 394,
#              'A3TLV6X0NJV934': 395,
#              'AXYIDAFJ8KCDM': 396,
#              'AAO9MM8RYVXZ': 397,
#              'A1VMDYBJRZ0M12': 398,
#              'A2VPSHOKIKSLJY': 399,
#              'A2Y4QMRYZ5J208': 400,
#              'AXJ529STIZPYJ': 401,
#              'A2UBXSS9E40GMV': 402,
#              'A2JP637GJSG9HP': 403,
#              'APQQDSTMZZN3T': 404,
#              'A39HPWLEGHKX8U': 405,
#              'A2W25AX6M2JKQQ': 406,
#              'A132VQ7JC6IN3H': 407,
#              'A3HJHV83O2U8BL': 408,
#              'ANRXH0BVEAR6B': 409,
#              'A1USW9OMWE8DVP': 410,
#              'A1O7GKN3IQY6B0': 411,
#              'A1LE9N9CZLPZ7Y': 412,
#              'A3FKUJWDRHTICR': 413,
#              'A3U447OH03AYN9': 414,
#              'ANXVC9YPIJBL4': 415,
#              'A3KVJPH3ZASIN2': 416,
#              'A1RE9J2T97QX8L': 417,
#              'AXIIWIAYJ8WDI': 418,
#              'A1WD8OCYPER4ZK': 419,
#              'A1MWTILB9DZSLZ': 420,
#              'A2DGP3CC6D0TKL': 421,
#              'A3A90CELVLOUP6': 422,
#              'A1087KNFOF40VD': 423,
#              'A1JP0E8A19XBW': 424,
#              'A13YHX8QAM9SXX': 425,
#              'A1IF665UA9UNI2': 426,
#              'A3SZUDMQ8L8C2R': 427,
#              'ARF6NZ2PH6MCB': 428,
#              'A2R1LE5SFJ1GXP': 429,
#              'AATWFX0ZZSE6C': 430,
#              'A2B1MUUAXTMICJ': 431,
#              'A367UX06631R8X': 432,
#              'AKCPXU46KZIY7': 433,
#              'A3CSC13HG2JXB6': 434,
#              'A2BW4GFLW3YSKE': 435,
#              'AC3A2NNK202S7': 436,
#              'A1SM3YUTM0C135': 437,
#              'A3W1GWLJC3PLX9': 438,
#              'A1ZI2MMAQVV3SJ': 439,
#              'A247DGX9O50ILT': 440,
#              'A16QJ424UMZVWR': 441,
#              'A3KBMS59165TUN': 442,
#              'AULPUTSN4SUNB': 443,
#              'A3B6TOMVGHAJTP': 444,
#              'A2N9KHMVKPH111': 445,
#              'A3U9QPKB17JZYS': 446,
#              'A1ENBOTX03172S': 447,
#              'AUVZI9EOH3FYX': 448,
#              'AXQJG7M1ARMKR': 449,
#              'AJEJYTTARQXN0': 450,
#              'A24ZH91LIJ3DKX': 451,
#              'ADEOYOY6I8GW3': 452,
#              'A67LMCVAH868U': 453,
#              'A3461WXN27BV0F': 454,
#              'A20D8ILFNFVS7N': 455,
#              'A1W4168AZHS0Y5': 456,
#              'AZ2WIB5P2QKOS': 457,
#              'A3I2ESD62IHM85': 458,
#              'A3GSTWRM0DOU86': 459,
#              'A1OXOGKSVD1XR9': 460,
#              'A2UF34QX6DJJCV': 461,
#              'A3FSYXF080S225': 462,
#              'AMACXKD1SBM6V': 463,
#              'AQNSQW4495SG0': 464,
#              'A1LIHSIZX7XMFI': 465,
#              'A3I17QUM0JKQ1D': 466,
#              'A1THLNAVFL30RY': 467,
#              'ANWSTGVLYXCHK': 468,
#              'AHAL5UKWCVN3O': 469,
#              'A1XGSMXS6SEL77': 470,
#              'A3MZWM75KSM1P6': 471,
#              'ANZZTTD7K3HAT': 472,
#              'A2GCGQL6OBLI8X': 473,
#              'A1Q8NI3FSG73OS': 474,
#              'A1DX3FH6C2U995': 475,
#              'AEECAAHZLYWRH': 476,
#              'A1S9W9A986D3KF': 477,
#              'A2C8N6W0XPYJB0': 478,
#              'A1AP1QGW95TVQ3': 479,
#              'A31UON2G6JOOVH': 480,
#              'A2EN3VH0ZKOR5H': 481,
#              'A3P6OBIFSB5CZO': 482,
#              'A2KSQWF4WGDERQ': 483,
#              'AULE7S5JPTJI2': 484,
#              'A2U49JQCT43OK7': 485,
#              'A3CI4JQKMWDR7D': 486,
#              'A38BYLWUASQ1M2': 487,
#              'A32CGZPC1N4ORJ': 488,
#              'A31JZMEJ7N9TQG': 489,
#              'A1IBY7WCE79K3X': 490,
#              'A2V0YBZ3X61VRP': 491,
#              'A1HG11K8O2D2C8': 492,
#              'A2NIH8JB9AL786': 493,
#              'A2IVAOKYIPD5HR': 494,
#              'A1ZQ11M7FOKTJA': 495,
#              'A3E2FGR7OTA351': 496,
#              'A1RS9DWUTDP0SD': 497,
#              'A3VY95PLLNSWNS': 498,
#              'A1HFT68GJ42LTM': 499,
#              'AITBK7EQSSKN8': 500,
#              'A3M81XV6J2561Q': 501,
#              'A2U7J3BCYQZWA8': 502,
#              'A1W82YQWM6KJ7W': 503,
#              'A426YWSW5GA24': 504,
#              'ASHDMDG0STZU6': 505,
#              'AVV5AKK829T3K': 506,
#              'AYIN6ARIRV55J': 507,
#              'A34JP8QRZRS7W5': 508,
#              'A1UCMY6JQM8FQ4': 509,
#              'A1I6EXBK95N4FH': 510,
#              'A3BR7VN9E0XYQ2': 511,
#              'A2A5FBW4HJKWBB': 512,
#              'A1KGON6Z3RR0FN': 513,
#              'A13Z644W9QLX3P': 514,
#              'A3BRRMYA0WCZRH': 515,
#              'A68BBGP3BA8NE': 516,
#              'A1VS427VTL2CG3': 517,
#              'A2LKA6528TZOR7': 518,
#              'A2RDXNL7XJ1UBN': 519,
#              'AVRW667ALFFHU': 520,
#              'A1S011SMHQ4Y1G': 521,
#              'A1TIW17I823XUG': 522,
#              'A84ST3SKSC6V0': 523,
#              'A1CKZC8RUBGK27': 524,
#              'AHVM1K3YGXMAE': 525,
#              'A2SX88ZKFUNXKW': 526,
#              'AHG0N8GME19U6': 527,
#              'AXR9URSWA4832': 528,
#              'A3IW9TTG36O24X': 529,
#              'A15NDUR69UAT7Y': 530,
#              'A3IO6Q6GZUY2ZE': 531,
#              'A1QRST0A3IQIEF': 532,
#              'A2R19YNN9DEN9N': 533,
#              'A3NTRVD2EH4HCI': 534,
#              'AZE1M6KCHZDSE': 535,
#              'A1EFTVHUX41BL7': 536,
#              'A3DECRYWZZM0SO': 537,
#              'A1QW9ZCEC2T2QQ': 538,
#              'A23SNLBXAJLKKY': 539,
#              'A3RIRLKTU5GEB0': 540,
#              'A3LFBD2DHDWG9E': 541,
#              'A2ROXHG7R0GHAL': 542,
#              'A2ONZBCQ66YDVG': 543,
#              'A3D2XMRV8DSK3J': 544,
#              'A2595600YN6FWV': 545,
#              'A2WB4823XOBRFA': 546,
#              'A26GYE5M4S5B70': 547,
#              'A29E6SX1KGBZYG': 548,
#              'A31MK9C43D3JF': 549,
#              'A3LCRX9T05U719': 550,
#              'A3VQFUAB6WQXMU': 551,
#              'AA3EFAVNZ9NWH': 552,
#              'A37O13FZ4AYUKN': 553,
#              'A3AVD37BSKMMDL': 554,
#              'AB37V9TAU054F': 555,
#              'A1MVH1WLYDHZ49': 556,
#              'A278V4RQOW79GG': 557,
#              'A3IS7IWI3RFS47': 558,
#              'A1VHDGG2CXBQ6T': 559,
#              'A24VCOP0IWU4IE': 560,
#              'AGI184WCALGXG': 561,
#              'A1C2H5BL9SMIWA': 562,
#              'A2LFR2GPEK3WQI': 563,
#              'A2L4J1WGHJMXRC': 564,
#              'AW1OGWTQAW85': 565,
#              'A1WGDEQCX7C852': 566,
#              'A1HPXZPXE50KKI': 567,
#              'A3N6YUPAIOJLSP': 568,
#              'A1HRHP1ZEI90NS': 569,
#              'AKNTHOKT9EGZA': 570,
#              'A3JEHY6YI4OQLP': 571,
#              'A360OF9QBC2KJF': 572,
#              'AZDK9LBE85R5T': 573,
#              'AKM6LM8Y49TYV': 574,
#              'A3VRU93Y1A6P27': 575,
#              'A2Q3JAF2FM9O4S': 576,
#              'A3LPL35P7FH78Y': 577,
#              'A2X7NFHRIHLMXJ': 578,
#              'A2YZCDQIAZIX1Q': 579,
#              'A2U1FZGO9FMGEK': 580,
#              'A3G7NU3Z79F6EA': 581,
#              'A35SNSDRNE9P8Q': 582,
#              'AWP0JM6XEVGIE': 583,
#              'A1GALZCXD8FHOR': 584,
#              'A30LY0QBWDH1UA': 585,
#              'ADKX4RWKZUDKN': 586,
#              'A3EVX4WNY8HNHK': 587,
#              'A19RPL8O9I3T30': 588,
#              'A3AHQZ396HJ7EH': 589,
#              'A3VNORPBAQEWA6': 590,
#              'AD8VA7Z8ZAGAM': 591,
#              'A36UPTY3491XUJ': 592,
#              'A1Y1F6YLDZGS3X': 593,
#              'A2WGVKP2OE07BV': 594,
#              'A15HQ3V82ANDX': 595,
#              'A2R7GNJ8FEFQ17': 596,
#              'A27XFNU6UX20CA': 597,
#              'A1QO2POWYK1XWP': 598,
#              'A2ODLXAUF86OQ1': 599,
#              'A134HFABW6BMZL': 600,
#              'A1HPDW9VZU33K4': 601,
#              'A2EFKDYHXUM65C': 602,
#              'A502QHHI91ENR': 603,
#              'A1U0VFD1CT4BSR': 604,
#              'ACCRTG2GO2ZAU': 605,
#              'A1EVUIUP748XXT': 606,
#              'A17CEGI6RXST2U': 607,
#              'A2UXF6KIVCHSRZ': 608,
#              'A29GLP5M4BN4GW': 609,
#              'A3K0MNJHO7R2MG': 610,
#              'A2A54AA1PYLXSS': 611,
#              'A26ACZTVWFY1IZ': 612,
#              'A460Q027OS30P': 613,
#              'A2KHZB6YL7DPRO': 614,
#              'A1CKBNRAS6MKNB': 615,
#              'A3DP4CFYQJIMUJ': 616,
#              'A1AX779H9OY7KX': 617,
#              'A2P0LKQU3MG7V0': 618,
#              'A3ZCY3JXFQWVN': 619,
#              'A1Z7MHOAWXRJBP': 620,
#              'AXN8U1K9N1XCZ': 621,
#              'A14GJJGQ4ABRJS': 622,
#              'A1J14LNFQ7O80T': 623,
#              'AICM4PAOOEN3S': 624,
#              'A2ED7ZZHTO3ZGY': 625,
#              'A15XWZX260ORFF': 626,
#              'A1YKUBH4Q408KH': 627,
#              'A3T79VHPTR9J97': 628,
#              'A2LAKH7K69VKK7': 629,
#              'A1POGQGNJ31Y7A': 630,
#              'A1D5S5INFKY6SE': 631,
#              'AOS5B22QY4H': 632,
#              'A2YH7F9YH12NIS': 633,
#              'A3RQ2JT91LTUML': 634,
#              'A26YHXBMNWDU95': 635,
#              'A1XOZ4YKN1VW20': 636,
#              'ANJLE4GOQY9FP': 637,
#              'A2PQNWBTVJ8MJ9': 638,
#              'AFJY469J3WGVO': 639,
#              'A12XV8Y54NT4PN': 640,
#              'A2R8H2MAC53C0N': 641,
#              'A1PM3SKPMA78D0': 642,
#              'AOP6D2C2XWST': 643,
#              'A3B0AB5HSWDSD2': 644,
#              'A1I8UYJGDQV98X': 645,
#              'A2ABKNJHAKPFEN': 646,
#              'AJINQYYYMVP8F': 647,
#              'A1YIEWVHWOQL24': 648,
#              'A3PHW1UYLKIMH1': 649,
#              'A3BXSR4ZFZS72V': 650,
#              'A3MDAKNSDDYGVU': 651,
#              'AGUMYIY3DFG9G': 652,
#              'A3G3630BY2HULX': 653,
#              'ADS99W8WMEXZ2': 654,
#              'A2DAVZ0XIKHHLM': 655,
#              'A1HY2WHFKKRGQU': 656,
#              'AP8EXADSLHZET': 657,
#              'A2X8VVKKP8END5': 658,
#              'A265SU6RW4ZAPY': 659,
#              'A2GIX9PLVPHFMM': 660,
#              'A586MUJ8PXY2A': 661,
#              'A21XHU9D672WYM': 662,
#              'AYW22SIH4BSI7': 663,
#              'AC5RPG819HKKI': 664,
#              'A24L9VQJR0SC1C': 665,
#              'A3U0CG57HIXDSD': 666,
#              'A37P779CLO36O2': 667,
#              'A1G57Y1WMMCNTP': 668,
#              'A15PF3UVSYVWH6': 669,
#              'ATZLO2NSO5C3C': 670,
#              'ANVWRHYZMGHIA': 671,
#              'A24C5LUOTVOYTK': 672,
#              'A3G6IKGM9O3WH5': 673,
#              'ASEAA7K44MZUZ': 674,
#              'A2P2Y1DRG5LNHX': 675,
#              'AA3KEAOFOXG90': 676,
#              'A2CGORRQGDEL37': 677,
#              'A34FJLXQ66BWPG': 678,
#              'A30C2ZPWDLE5NV': 679,
#              'A2G37XJHU5CX6': 680,
#              'A20IMBRGCWEV9R': 681,
#              'A3Q824U5PW1W4G': 682,
#              'A3UKPBTB65LLH6': 683,
#              'A14B4BR3UV38X0': 684,
#              'A2CLFJA3MY29LR': 685,
#              'A2H82MAEZ9IPUT': 686,
#              'A2O9RDCYVOPCN1': 687,
#              'A1TMYNF0F7U0C0': 688,
#              'A3PRNX5PAHT6BH': 689,
#              'A19YOR4TA9J2RK': 690,
#              'A1QYTCXVMPWA2E': 691,
#              'A2IWXP0TWG553L': 692,
#              'A99KOKEWNJOXB': 693,
#              'A3M7JD51RIFPNL': 694,
#              'A37QPYNVOZQ6LT': 695,
#              'A19PXUQ68MWS3M': 696,
#              'A1NUP461GQXJNF': 697,
#              'A15FPV8WAFQ04H': 698,
#              'A2TF2KE25HW72N': 699,
#              'A3AMIGUD1UCDF': 700,
#              'A15UMZA8I7ZL1O': 701,
#              'A3LB4YNC45K9M': 702,
#              'A15MRMD6FH3035': 703,
#              'AP0I52BS91F79': 704,
#              'A2DMFZESTQN151': 705,
#              'A36ICUXNCW9GMV': 706,
#              'A14JIZXOO0KY1': 707,
#              'A2ZXTGSHCZT643': 708,
#              'A2LHE7KRBEZPVB': 709,
#              'A2O7TUXIWQ79HX': 710,
#              'A3C38H62E0UXLA': 711,
#              'A3Q7HWIL61OWPZ': 712,
#              'A26M19HKRFQYTQ': 713,
#              'AGY18FDBPH6MB': 714,
#              'A16X3MH2FG1JOD': 715,
#              'A1PSZRHNMI5NX3': 716,
#              'AJDNV379EM66C': 717,
#              'A2QGG3OQY7BSP3': 718,
#              'A826W2Y0OQ5S7': 719,
#              'A1FKAONTKJ21QC': 720,
#              'A1G75ODP2ERGTJ': 721,
#              'ATHB818L77BI8': 722,
#              'A1124AVYIIU7ZA': 723,
#              'A11PY3GIKYCQBS': 724,
#              'A1NSGH5K4F4UIC': 725,
#              'AA0IJ5KM40ABZ': 726,
#              'A2GBJUB44UK3LO': 727,
#              'A2QELFSPAXTK44': 728,
#              'AJZ6BJ38MF78W': 729,
#              'A3I3OSZR5GDGV3': 730,
#              'A2WI3QJA55S0YP': 731,
#              'A3CU7BX8LGW86S': 732,
#              'A3RH38CRPET069': 733,
#              'A3270XHBUVTJRU': 734,
#              'A1X2MEBEM0FMBU': 735,
#              'A3D1393GR3SH2M': 736,
#              'AFJOSH1UTYUAK': 737,
#              'ANC4BPHE3CK20': 738,
#              'AI4QYQ75JK84M': 739,
#              'A2KXWQEO9ZBNQW': 740,
#              'AN6QS4JJLZOZJ': 741,
#              'A2Y73AS8Q8B4ZD': 742,
#              'A1A8S6UWPCXFEF': 743,
#              'A2Q7OJTVPIO2XH': 744,
#              'A2ASP462CGXSMN': 745,
#              'A3M5CEQWC2ENSS': 746,
#              'A1FV7W4SZD9BVO': 747,
#              'A29B4NIO3N8ZTA': 748,
#              'A3KVCHF2QXJKN5': 749,
#              'A3P4T1DKRWTL36': 750,
#              'A2MBYDJV2VGHMO': 751,
#              'A17KNKWCU3VQCC': 752,
#              'A2CWUM49ZWMGEY': 753,
#              'A16WND1BVJCQJV': 754,
#              'A3CBBQQXA7VV6J': 755,
#              'A1ESBB4RNIX0LN': 756,
#              'A3VEFQ25OSXMOQ': 757,
#              'A38HJ96SG8ZZHX': 758,
#              'A25D01W0ITWHRA': 759,
#              'ANQYL9QWM000N': 760,
#              'A1RE1U5HE92MAW': 761,
#              'A7SVLX7YSPIBC': 762,
#              'A2GDMRYIOK1SUN': 763,
#              'A321F27MLVDUAG': 764,
#              'A23NFZ13VIQAQT': 765,
#              'A4ERQV4ZQDWVT': 766,
#              'A2Q5Z06V4PBOSD': 767,
#              'A23ZKEXVIAVEJN': 768,
#              'A2IRMI88I2UURO': 769,
#              'A1HGSBRTORZKZG': 770,
#              'AB4ELQX285UKL': 771,
#              'A1ENEUNA9U2FUE': 772,
#              'A2QLN0TVXRST8S': 773,
#              'AX4W19NEJ4O1T': 774,
#              'A1U16AFO4RLRS8': 775,
#              'AA5052SCGAYDA': 776,
#              'AIVRD7P36IYS7': 777,
#              'A24W4C1FOSRKVV': 778,
#              'A1POBZCAK5LHWE': 779,
#              'AT5APBVO80HIO': 780,
#              'A34VP9QWJUMPO3': 781,
#              'A2WSPH2G6SG08C': 782,
#              'A3HX5E2QG2FU1R': 783,
#              'A2LKI9329MCKU': 784,
#              'A1ML6RV84LYP4T': 785,
#              'A94QJ3Z8G7936': 786,
#              'A1U30MLH417OX7': 787,
#              'AUOJNV67EPVKC': 788,
#              'AEQELG3QUQRTP': 789,
#              'ALM43JVJ25WGW': 790,
#              'A8AB924DZS5OC': 791,
#              'A11O2YAN30LQEB': 792,
#              'A2F072IOCQD4DZ': 793,
#              'A1W8TURMFK3S33': 794,
#              'A2C3IUNCJEWKZ5': 795,
#              'A4D1K61JWEAAO': 796,
#              'A35RQBU8TRVNLV': 797,
#              'A3AFQMHH3PM1A0': 798,
#              'A1B55QR1FW824Y': 799,
#              'A1LO96FVEHGWJN': 800,
#              'A3P8SSQ21NTZ0C': 801,
#              'A37TFUSY61EFEB': 802,
#              'A81M9AEYSQMF9': 803,
#              'A1R0KDKU3WMJ0X': 804,
#              'A2BEHJMCLCXR10': 805,
#              'A1IE0N2D9P3CQ3': 806,
#              'A2KWMK01BFPK3W': 807,
#              'A3NW3R4S2VT3WK': 808,
#              'AHTYYLPB2BG22': 809,
#              'A1R1GN8MZ783LE': 810,
#              'A1FQH9GW2U8UTD': 811,
#              'AFO7J8O4TPBUL': 812,
#              'AHCNG15YD2Y8E': 813,
#              'A1469RVEKZYSO8': 814,
#              'A1R4VH5YM1TY5X': 815,
#              'AOKO5CEJ5C0ZA': 816,
#              'A2AP7FL9ZIFPUF': 817,
#              'A3I698XKVCG816': 818,
#              'A2OKZXVQ3PA3YI': 819,
#              'ACES6E6X5RF98': 820,
#              'A2V2WSB5AVI4N7': 821,
#              'A1WU3RDNM8Y8Q9': 822,
#              'A8OXPKYXXW7P9': 823,
#              'A17G8GQM941JTC': 824,
#              'A22GY8IOSBB9BG': 825,
#              'AMXY26ABPVDDA': 826,
#              'A2GM4L6CGV39KP': 827,
#              'A1QAMSDUULR1W6': 828,
#              'A2B9N8LRE4CG7O': 829,
#              'A1XK4VP74IB9TQ': 830,
#              'A1FKYXCEHQD42U': 831,
#              'A3OP3QKEND7XS8': 832,
#              'A3N8UOHGJU7ZO6': 833,
#              'A3MQ13NSITCPAD': 834,
#              'A80GO4MH6Q4AS': 835,
#              'A3E0HG31WM6C88': 836,
#              'ANNA1C2AYRVSA': 837,
#              'ABRLSEJNWZ67R': 838,
#              'A2RGKDL0ADPLSW': 839,
#              'A1JTRZ2D5IIULN': 840,
#              'AUN7Z2LOX2ZG9': 841,
#              'A2CLHJ5OJIEWZL': 842,
#              'A2G98PQZNMXV15': 843,
#              'A6DEWY5SVSR3R': 844,
#              'ABOX1YNXHU6UH': 845,
#              'A20CNSK3TB3JIA': 846,
#              'A1ACZ5J0QIDE36': 847,
#              'A18L9A64XNGVGU': 848,
#              'A39FIEDRWHC44C': 849,
#              'A1XLK3DLSDHM6L': 850,
#              'A2FJ135DKY6TXY': 851,
#              'A28QSM9UHLRQBV': 852,
#              'A20ZCHB9EV90D4': 853,
#              'ALA0U1ZI6GJMX': 854,
#              'A2K5ENSC9ANISE': 855,
#              'A1D2GOXZ3K5W3I': 856,
#              'A3S58J9HNVKP32': 857,
#              'A1FKTGYHIFWLHU': 858,
#              'A3VRTKN5QYKIXQ': 859,
#              'A3P3POLX82FIYT': 860,
#              'A3D8QRY6IC3CAB': 861,
#              'A2UMM1OXD6AU7M': 862,
#              'AD4KIQJ587RRK': 863,
#              'A21T0D2F7SKG5S': 864,
#              'AGI4J282HUVK3': 865,
#              'A3NX8BO569AGQZ': 866,
#              'AEUW6VD9XCVWD': 867,
#              'A1KGKPWWG61U42': 868,
#              'A3KZ21FSVUEZDB': 869,
#              'A3CG6YLYZJXQG4': 870,
#              'A2GZT0HEYEJUTO': 871,
#              'ACQD52DDVX4F7': 872,
#              'A4E9H23O2Q9SR': 873,
#              'A2L8MU0N2P5KPK': 874,
#              'A1HT81V0Z717H7': 875,
#              'A3LGUMVTF578UJ': 876,
#              'AF2ANMP5RBV4': 877,
#              'A361YX3SAP39PW': 878,
#              'A35R9UVCVX7QHY': 879,
#              'A3P4WHRRFVDEEC': 880,
#              'A22XPI3X0TDKT8': 881,
#              'A6K6Z2V4TUVZ7': 882,
#              'A18ZYBZLR66IWK': 883,
#              'A34OXK9SP7TNCT': 884,
#              'A1QQ4U4RTI0A1M': 885,
#              'AJDR39KQIMM99': 886,
#              'A2LFFIR1UZZHYP': 887,
#              'A3PPO2X5PJE1L9': 888,
#              'A35I3VJR2I65ZV': 889,
#              'A2LFYTX1544TZM': 890,
#              'A14BVDLAQH9ZXA': 891,
#              'A17INQNCZ1HMHL': 892,
#              'A2IDSN6T8QVRFE': 893,
#              'A1FZ01WC1JGVWJ': 894,
#              'A15E1U71O19I92': 895,
#              'A283C1ZL38MXBK': 896,
#              'A1WX6BYSC8VRA0': 897,
#              'A2BVV8ND8Q6S6A': 898,
#              'A2RLFKKO2U1KRY': 899,
#              'A29BKUBPWA1BP1': 900,
#              'A2D08K9XO3B5L3': 901,
#              'A38XYO1S5747MY': 902,
#              'A159S51Y0DTZXU': 903,
#              'A29FO5HWPH9PKX': 904,
#              'A3KVXROGIY42XS': 905,
#              'ABM0Q995KC344': 906,
#              'A9GIGJUB98JNR': 907,
#              'A177EE11AYO4XW': 908,
#              'A2P6EPQ906M3AJ': 909,
#              'A33GZWCRJJSOK3': 910,
#              'A1VYC0IRF6WNK2': 911,
#              'A1RGUZCCE2HN1K': 912,
#              'A177HLB30IAQNW': 913,
#              'A1R7IEYLALESKB': 914,
#              'AU3YIXELHMOO2': 915,
#              'A2ENPQM2SNDEV': 916,
#              'A2MJEY9HZHRF01': 917,
#              'A2IFN1FBRHOK7R': 918,
#              'A1JHGHQW6YCOZ0': 919,
#              'A3LAUW2UZ5SWS6': 920,
#              'A21LDGIEAVN45L': 921,
#              'A10VVWWZIFLPV9': 922,
#              'A3UPGIV1ZNYSPZ': 923,
#              'ARFP7DXIYEF35': 924,
#              'A16I7ELP95NLTR': 925,
#              'A2ONAIRSFW2QCN': 926,
#              'A2QBTXJEVMA1ZV': 927,
#              'A2FCIDI64WSBC6': 928,
#              'ADRY177V6FNXW': 929,
#              'A1PRPHWG22CKKG': 930,
#              'ANTOV8XD0YB0W': 931,
#              'A1D8LJYOS0XS5G': 932,
#              'A3T05FOORNQI18': 933,
#              'A389U7BPUTJRG3': 934,
#              'A29R49S8CV8YAO': 935,
#              'APW6ATNXGCEEN': 936,
#              'A17ST44YL27ER': 937,
#              'A35QFQI0M46LWO': 938,
#              'A3E37TD9Z4HXGT': 939,
#              'A14FTMH5H4NGIJ': 940,
#              'A20K0GPVMGXN9': 941,
#              'AKAMPNA389X6O': 942,
#              'A3RTEJFZK8KL5R': 943,
#              'A2IP2F3FRSWSRS': 944,
#              'A36FZXWN5UP08W': 945,
#              'A6WJX3XBNNETL': 946,
#              'A3MGIVZIUAI2CF': 947,
#              'A2TM7I63LF51L1': 948,
#              'A1XH8Q24KOSRTJ': 949,
#              'A26XM42ASRFHMU': 950,
#              'A3BEPLAGXAC7B5': 951,
#              'A1BZFRYSMNPVYF': 952,
#              'A2I7378BV33SWO': 953,
#              'A37C3BDZQY0X82': 954,
#              'A2BCPOPTEXYYE4': 955,
#              'A12DBY0RDJMO1J': 956,
#              'A23PMQTARXAPR2': 957,
#              'A3MKASSMJ4RKTR': 958,
#              'A20J67RTBV1XH9': 959,
#              'A10UHQH1YL5Q6B': 960,
#              'A1COGMXQ5XP2OA': 961,
#              'A3IL4WNBMGBJRY': 962,
#              'A2X4J1HYFTDTGJ': 963,
#              'A3NA5A8IJHLK7S': 964,
#              'A2GX4KWO3V42Z': 965,
#              'AK5UT7LSKEANL': 966,
#              'A1PGC1GEBY9CZU': 967,
#              'A31716GNN7P6B2': 968,
#              'A3JUQ2E799OC5B': 969,
#              'AZZX23UGJGKTT': 970,
#              'A2Y4ZUVCSLOZ9Z': 971,
#              'A3QPJI4YYOCG78': 972,
#              'A1WCY6IGGL4SJ': 973,
#              'A5HSIW7G91T2K': 974,
#              'A12SSZIN555FTL': 975,
#              'A1FNKB7Q8KG6YS': 976,
#              'A39YP9CD8AS6CQ': 977,
#              'A27UW82D16O33I': 978,
#              'A1VV9SB3ODA2W0': 979,
#              'A1OIQ0NU3WDK35': 980,
#              'A1H0P6B3FXET8K': 981,
#              'A2TY701IGHAXKX': 982,
#              'A3M2TMPK88UCSR': 983,
#              'A16GF8CPAOG1HO': 984,
#              'A39LKIPEIH1BC1': 985,
#              'A21LLSXH12HKT': 986,
#              'AYXFNO4OPWKBH': 987,
#              'AAGQNG7TITMMX': 988,
#              'A3DXDS8NSGTJ3W': 989,
#              'A131E28H6DRH61': 990,
#              'A35JWV3EZUEMW5': 991,
#              'A2GV5GI7X215XW': 992,
#              'A2IBIL55IMVC79': 993,
#              'A3ID7M8G9ZBJ5B': 994,
#              'AQEFGQHHC1RJ8': 995,
#              'A2ZAY1ANRCLXIJ': 996,
#              'A2WROWUBLQ9GZZ': 997,
#              'A1HJIDNAY31M20': 998,
#              'A7YRIRDOZZ2H7': 999,
#              ...})
